# %%
riding_bike = str(input("what is the name og the driver"))
age_of_the_driver = int(input("enter the age of the driver"))
hight = int(input("enter the hight of the person"))
if hight >= 120 :
    print("u can ride the bike")
    if age_of_the_driver > 18 :
        print("the cost of the bike per hour is: 12")
    else:
        print("the cost of the bike per hour is: 7")
else:
    print("u cant ride")
# Out:
# u can ride the bike
# the cost of the bike per hour is: 7

# %% [markdown]
# using elif i can write this code

# %%
riding_bike = str(input("what is the name og the driver"))
age_of_the_driver = int(input("enter the age of the driver"))
hight = int(input("enter the hight of the person"))
if hight >= 120 :
    print("u can ride the bike")
    if age_of_the_driver > 18 :
        print("the cost of the bike per hour is: 12")
    elif age_of_the_driver < 10:
        print("u cant ride")
    else:
        print("the cost of the bike per hour is: 7")
else:
    print("u cant ride")
# Out:
# u can ride the bike
# u cant ride

# %% [markdown]
# i got the logic in this program

# %% [markdown]
# bmi using the elif conditions

# %%
weight = int(input("what is the weight of ur body"))
height = int(input("what is the height of ur body:"))
bmi = weight/ (height **2)
print("the bmi is equal = ",bmi)
if bmi < 18.5:
    print("under weight")
elif 18.5 <= 25:
    print("normal weight")
else:
    print("over waighted")
# Out:
# the bmi is equal =  0.0125
# under weight

# %%
hight = int(input("what is the hight of the person"))
age = int(input("what is the age :"))
phots = str(input("u want photes ha"))
if hight >= 120:
    print("can ride")
elif age <12:
    print("u can pay 5 rs")
elif age <18:
    print("u have to pay 7rs")
elif age > 18:
    print("u have to pay 12 rs")
if phots == "yes":
    print("bill is 3")
else:

# %%
print("welcome to the rollercoster")
hight =  int(input("what is the hight of the person:"))
bill = 0
if hight >= 120:
    print("you can ride the rollarcoaster")
    age = int(input("what is the age of the person "))
    if age <=12 :
        bill = 5
        print("child ticket are 5rs")
    elif age <= 12:
        bill = 7
        print("youth ticket are 7rs") 
    elif age <= 18:
        bill = 7
        print("adult ticket is 12rs") 
    else:
        print("adult ticket is 12rs")
    wants_photo = input("do u want to have a photo take? type y for yes and n for no ")
    if wants_photo == "y"   :
        #add 3 to there bill 
        bill += 3
    print(f"your dinal bill is {bill}")
else:
    print("u are not a taller person u are not allowed")
# Out:
# welcome to the rollercoster
# you can ride the rollarcoaster
# child ticket are 5rs
# your dinal bill is 8

# %% [markdown]
# pizza counting using if else statements

# %%
print("welcome to python pizza deliveries:")
size = input("what is the size do you want ? s , m, or l")
pepperoni = input("dou want pepperoni on your pizza? y and n")
extra_cheese = input("do you want extra cheese? y or n")
bill = 0
if size == "s":
    bill = 15
    if pepperoni == "y":
        bill += 2
        print(f"the cost of the pizza is {bill}")
        if extra_cheese =="y":
            bill += 1
            print(f"the cost of the pizza is {bill}")
else :
    print(f"the bill for small pizza is {bill}")
if size == "m":
    bill = 15
    if pepperoni == "y":
        bill += 3
        print(f"the cost of the pizza is {bill}")
        if extra_cheese =="y":
            bill += 1
            print(f"the cost of the pizza is {bill}")
else :
    print(f"the bill for small pizza is {bill}")
# Out:
# welcome to python pizza deliveries:
# the bill for small pizza is 0
# the cost of the pizza is 18
# the cost of the pizza is 19

# %%
print("welcome to python pizza deliveries:")
size = input("what is the size do you want ? s , m, or l")
pepperoni = input("dou want pepperoni on your pizza? y and n")
extra_cheese = input("do you want extra cheese? y or n")
bill = 0
if size == "s":
    bill += 15
elif size == "m":
    bill += 20
elif size == "l":
    bill +=25
else:
    print("wrong inputs")  
if pepperoni == "y":
    if size == "s":
        bill +=2
    else:
        bill += 3   
if extra_cheese == "y":
    bill +=1
print(f"your final bill is {bill}")
# Out:
# welcome to python pizza deliveries:
# your final bill is 24
